# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
BGR = np.asarray([14.88,14.97,15.1,15.19,15.31,15.26,15.17,15.11,15.18,15.15,15.22,15.28,15.15,15.18,15.25,15.31,15.17,15.1,15.06,15.03,15.13])
KRP = np.asarray([19.37,19.31,19.31,19.32,19.31,19.23,19.25,19.31,19.4,19.34,19.25,19.2,19.04,18.96,18.92,18.98,19,18.93,18.97,19.04,19.12])
LFI = np.asarray([4.13,4.13,4.13,4.15,4.09,4.09,4.07,4.11,4.07,4.02,4,3.99,3.93,3.93,3.88,3.89,3.94,3.97,3.95,3.92,3.97])
POP = np.asarray([249.16,249.25,249.39,249.41,249.25,249.21,249.28,249.25,249.22,249.13,249.11,249.17,249.13,249.11,248.97,248.92,248.82,248.86,248.78,248.86,248.92])
PRO = np.asarray([132.39,132.33,132.38,132.33,132.47,132.55,132.5,132.61,132.69,132.69,132.6,132.55,132.52,132.6,132.5,132.44,132.5,132.55,132.66,132.52,132.44])
RWC = np.asarray([203.88,203.8,203.89,203.88,203.72,203.69,203.78,203.83,203.89,203.89,203.97,204.02,203.91,203.92,203.94,204,203.92,203.86,203.89,203.72,203.72])
UNI = np.asarray([185.53,185.61,185.55,185.61,185.52,185.5,185.55,185.49,185.42,185.41,185.36,185.38,185.46,185.38,185.32,185.39,185.22,185.17,185.19,185.28,185.28])
UPA = np.asarray([175.94,176.05,176.1,176.16,176.22,176.17,176.13,176.16,176.19,176.3,176.22,176.21,176.17,176.17,176.08,176.08,175.92,175.86,175.8,175.8,175.88])
prices = [BGR,KRP,LFI,POP,PRO,RWC,UNI,UPA]

# %%
zvars = [(x-np.mean(x))/np.std(x) for x in prices]
stdevs = [np.std(x) for x in prices]

# %%
t = np.arange(0,21)
fig,ax = plt.subplots()
for x in zvars:
    ax.plot(t,x)

# %%
[np.mean(x) for x in prices]
# Out:
# [15.152380952380952,
#  19.16952380952381,
#  4.017142857142857,
#  249.10476190476186,
#  132.5152380952381,
#  203.86285714285714,
#  185.41047619047623,
#  176.0766666666667]

# %%
high_index = [0,1,2,5]
low_index = [3,4,6,7]
high_pchange = np.asarray([stdevs[x] for x in high_index])
low_pchange = np.asarray([stdevs[x] for x in low_index])

# %%
high_pchange, low_pchange, np.mean(high_pchange), np.std(high_pchange), np.mean(low_pchange),np.std(low_pchange)
# Out:
# (array([0.10555544, 0.1611706 , 0.08625228, 0.09160697]),
#  array([0.18183245, 0.10367619, 0.12937491, 0.146005  ]),
#  0.1111463223189183,
#  0.029728717131430788,
#  0.14022213850107573,
#  0.028364271884478487)
